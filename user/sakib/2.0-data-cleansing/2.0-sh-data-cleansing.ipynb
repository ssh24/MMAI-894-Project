# %%
# import libraries
import numpy as np
import os
import pandas as pd

# %%
# environment settings
cwd = os.getcwd()

# %%
# set the current working directory
def setwd(wd):
    os.chdir(wd)

# %%
# load the dataframe
def load_data(file_name):
    return pd.read_csv(file_name)

# %%
# get the shape of the dataframe
def get_shape(data):
    return data.shape

# %%
# get the list of columns
def get_columns(data):
    return list(data.columns)

# %%
# check if any columns has null values
def check_null_values(data):
    return data.isnull().any()

# %%
# get the head of the dataframe
def get_head(data, limit=5):
    return data.head(limit)

# %%
# get the tail of the dataframe
def get_tail(data, limit=5):
    return data.tail(limit)

# %%
# get the description of the dataframe
def get_description(data, transpose=False):
    if (transpose):
        return data.describe().transpose()
    return data.describe()

# %%
# get the correlation matrix
def get_correlation_matrix(data, gradient=False):
    if (gradient):
        return data.corr().style.background_gradient()
    return data.corr()

# %%
# set working directory
setwd(os.path.join(cwd, 'data'))

# %%
# load initial data
data = load_data('0.0-sh-data-JPM.csv')

# %%
# get the shape of the data
get_shape(data)
# Out:
# (2517, 13)

# %%
# get the list of columns
get_columns(data)
# Out:
# ['Date',
#  'Open',
#  'High',
#  'Low',
#  'Close',
#  'Volume',
#  'Dividend',
#  'Split',
#  'Adj_Open',
#  'Adj_High',
#  'Adj_Low',
#  'Adj_Close',
#  'Adj_Volume']

# %%
# get null value check
check_null_values(data)
# Out:
# Date          False
# Open          False
# High          False
# Low           False
# Close         False
# Volume        False
# Dividend      False
# Split         False
# Adj_Open      False
# Adj_High      False
# Adj_Low       False
# Adj_Close     False
# Adj_Volume    False
# dtype: bool

# %%
# get the head of the data
get_head(data)
# Out:
#          Date   Open   High    Low  Close      Volume  Dividend  Split  \
# 0  2008-12-09  35.67  35.70  33.66  33.96  65827700.0       0.0    1.0
# 1  2008-12-10  34.40  34.96  33.08  33.52  47919600.0       0.0    1.0
# 2  2008-12-11  32.60  32.76  29.74  29.94  70746400.0       0.0    1.0
# 3  2008-12-12  28.44  31.22  28.01  30.94  59939000.0       0.0    1.0
# 4  2008-12-15  29.34  29.78  28.17  28.63  51629100.0       0.0    1.0
#
#     Adj_Open   Adj_High    Adj_Low  Adj_Close  Adj_Volume
# 0  28.447812  28.471738  26.844782  27.084040  65827700.0
# 1  27.434952  27.881568  26.382216  26.733128  47919600.0
# 2  25.999402  26.127007  23.718473  23.877979  70746400.0
# 3  22.681687  24.898814  22.338750  24.675506  59939000.0
# 4  23.399462  23.750374  22.466355  22.833217  51629100.0

# %%
# get the tail of the data
get_tail(data)
# Out:
#             Date    Open      High     Low   Close      Volume  Dividend  \
# 2512  2018-11-30  109.85  111.3200  109.58  111.19  18652458.0       0.0
# 2513  2018-12-03  112.38  112.8900  111.74  112.24  16032195.0       0.0
# 2514  2018-12-04  111.60  111.6000  106.73  107.23  23553050.0       0.0
# 2515  2018-12-06  105.01  105.3600  102.88  105.19  27209129.0       0.0
# 2516  2018-12-07  105.16  106.9817  102.91  103.29  19247446.0       0.0
#
#       Split  Adj_Open  Adj_High  Adj_Low  Adj_Close  Adj_Volume
# 2512    1.0    109.85  111.3200   109.58     111.19  18652458.0
# 2513    1.0    112.38  112.8900   111.74     112.24  16032195.0
# 2514    1.0    111.60  111.6000   106.73     107.23  23553050.0
# 2515    1.0    105.01  105.3600   102.88     105.19  27209129.0
# 2516    1.0    105.16  106.9817   102.91     103.29  19247446.0

# %%
# get the description of the data
get_description(data, transpose=True)
# Out:
#              count          mean           std           min           25%  \
# Open        2517.0  5.923777e+01  2.405510e+01  1.535000e+01  4.098000e+01
# High        2517.0  5.980810e+01  2.414035e+01  1.729000e+01  4.140000e+01
# Low         2517.0  5.864868e+01  2.396363e+01  1.496000e+01  4.055000e+01
# Close       2517.0  5.923792e+01  2.404006e+01  1.590000e+01  4.092000e+01
# Volume      2517.0  2.767582e+07  2.225182e+07  3.680043e+06  1.380260e+07
# Dividend    2517.0  5.419150e-03  4.829396e-02  0.000000e+00  0.000000e+00
# Split       2517.0  1.000000e+00  0.000000e+00  1.000000e+00  1.000000e+00
# Adj_Open    2517.0  5.394852e+01  2.581752e+01  1.239044e+01  3.369654e+01
# Adj_High    2517.0  5.445861e+01  2.594013e+01  1.395640e+01  3.413282e+01
# Adj_Low     2517.0  5.342192e+01  2.568699e+01  1.207563e+01  3.333833e+01
# Adj_Close   2517.0  5.394832e+01  2.580202e+01  1.283440e+01  3.374518e+01
# Adj_Volume  2517.0  2.767582e+07  2.225182e+07  3.680043e+06  1.380260e+07
#
#                      50%           75%           max
# Open        5.526000e+01  6.683000e+01  1.191300e+02
# High        5.583000e+01  6.718990e+01  1.193300e+02
# Low         5.468000e+01  6.627000e+01  1.180800e+02
# Close       5.526000e+01  6.671000e+01  1.187700e+02
# Volume      2.018895e+07  3.370562e+07  2.172942e+08
# Dividend    0.000000e+00  0.000000e+00  8.000000e-01
# Split       1.000000e+00  1.000000e+00  1.000000e+00
# Adj_Open    4.905711e+01  6.239461e+01  1.183089e+02
# Adj_High    4.943276e+01  6.278519e+01  1.184182e+02
# Adj_Low     4.861395e+01  6.194252e+01  1.172661e+02
# Adj_Close   4.906474e+01  6.244089e+01  1.178124e+02
# Adj_Volume  2.018895e+07  3.370562e+07  2.172942e+08

# %%
# rename columns using camel case criteria
data.columns = ['date', 'open', 'high', 'low', 'close', 'volume', 'dividend', 'split', 'adjOpen', 'adjHigh', 'adjLow', 'adjClose', 'adjVolume']
get_columns(data)
# Out:
# ['date',
#  'open',
#  'high',
#  'low',
#  'close',
#  'volume',
#  'dividend',
#  'split',
#  'adjOpen',
#  'adjHigh',
#  'adjLow',
#  'adjClose',
#  'adjVolume']

# %%
# get the correlation matrix
get_correlation_matrix(data, gradient=True)
# Out:
# /Users/sakib@ibm.com/anaconda2/lib/python2.7/site-packages/matplotlib/colors.py:504: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
# <style  type="text/css" >
#     #T_f13ef3ab_03fa_11e9_979c_88e9fe65d0c0row0_col0 {
#             background-color:  #023858;
#         }    #T_f13ef3ab_03fa_11e9_979c_88e9fe65d0c0row0_col1 {
#             background-color:  #023858;
#         }    #T_f13ef3ab_03fa_11e9_979c_88e9fe65d0c0row0_col2 {
#             background-color:  #023858;
#         }    #T_f13ef3ab_03fa_11e9_979c_88e9fe65d0c0row0_col3 {
#             background-color:  #023858;
#         }    #T_f13ef3ab_03fa_11e9_979c_88e9fe65d0c0row0_col4 {
#             background-color:  #fef6fb;
#         }    #T_f13ef3ab_03fa_11e9_979c_88e9fe65d0c0row0_col5 {
#             background-color:  #f4edf6;
#         }    #T_f13ef3ab_03fa_11e9_979c_88e9fe65d0c0row0_col6 {
#             background-color:  #fff7fb;
#         }    #T_f13ef3ab_03fa_11e9_979c_88e9fe65d0c0row0_col7 {
#             background-color:  #023858;
#         }    #T_f13ef3ab_03fa_11e9_979c_88e9fe65d0c0row0_col8 {
#             background-color:  #023858;
#         }    #T_f13ef3ab_03fa_11e9_979c_88e9fe65d0c0row0_col9 {
#             background-color:  #023858;
#         }    #T_f13ef3ab_03fa_11e9_979c_88e9fe65d0c0row0_col10 {
#             background-color:  #023858;
#         }    #T_f13ef3ab_03fa_11e9_979c_88e9fe65d0c0row0_col11 {
#             background-color:  #fef6fb;
#         }    #T_f13ef3ab_03fa_11e9_979c_88e9fe65d0c0row1_col0 {
#             background-color:  #023858;
#         }    #T_f13ef3ab_03fa_11e9_979c_88e9fe65d0c0row1_col1 {
#             background-color:  #023858;
#         }    #T_f13ef3ab_03fa_11e9_979c_88e9fe65d0c0row1_col2 {
#             background-color:  #023858;
#         }    #T_f13ef3ab_03fa_11e9_979c_88e9fe65d0c0row1_col3 {
#             background-color:  #023858;
#         }    #T_f13ef3ab_03fa_11e9_979c_88e9fe65d0c0row1_col4 {
#             background-color:  #fef6fa;
#         }    #T_f13ef3ab_03fa_11e9_979c_88e9fe65d0c0row1_col5 {
#             background-color:  #f4edf6;
#         }    #T_f13ef3ab_03fa_11e9_979c_88e9fe65d0c0row1_col6 {
#             background-color:  #fff7fb;
#         }    #T_f13ef3ab_03fa_11e9_979c_88e9fe65d0c0row1_col7 {
#             background-color:  #023858;
#         }    #T_f13ef3ab_03fa_11e9_979c_88e9fe65d0c0row1_col8 {
#             background-color:  #023858;
#         }    #T_f13ef3ab_03fa_11e9_979c_88e9fe65d0c0row1_col9 {
#             background-color:  #023858;
#         }    #T_f13ef3ab_03fa_11e9_979c_88e9fe65d0c0row1_col10 {
#             background-color:  #023858;
#         }    #T_f13ef3ab_03fa_11e9_979c_88e9fe65d0c0row1_col11 {
#             background-color:  #fef6fa;
#         }    #T_f13ef3ab_03fa_11e9_979c_88e9fe65d0c0row2_col0 {
#             background-color:  #023858;
#         }    #T_f13ef3ab_03fa_11e9_979c_88e9fe65d0c0row2_col1 {
#             background-color:  #023858;
#         }    #T_f13ef3ab_03fa_11e9_979c_88e9fe65d0c0row2_col2 {
#             background-color:  #023858;
#         }    #T_f13ef3ab_03fa_11e9_979c_88e9fe65d0c0row2_col3 {
#             background-color:  #023858;
#         }    #T_f13ef3ab_03fa_11e9_979c_88e9fe65d0c0row2_col4 {
#             background-color:  #fff7fb;
#         }    #T_f13ef3ab_03fa_11e9_979c_88e9fe65d0c0row2_col5 {
#             background-color:  #f4edf6;
#         }    #T_f13ef3ab_03fa_11e9_979c_88e9fe65d0c0row2_col6 {
#             background-color:  #fff7fb;
#         }    #T_f13ef3ab_03fa_11e9_979c_88e9fe65d0c0row2_col7 {
#             background-color:  #023858;
#         }    #T_f13ef3ab_03fa_11e9_979c_88e9fe65d0c0row2_col8 {
#             background-color:  #023858;
#         }    #T_f13ef3ab_03fa_11e9_979c_88e9fe65d0c0row2_col9 {
#             background-color:  #023858;
#         }    #T_f13ef3ab_03fa_11e9_979c_88e9fe65d0c0row2_col10 {
#             background-color:  #023858;
#         }    #T_f13ef3ab_03fa_11e9_979c_88e9fe65d0c0row2_col11 {
#             background-color:  #fff7fb;
#         }    #T_f13ef3ab_03fa_11e9_979c_88e9fe65d0c0row3_col0 {
#             background-color:  #023858;
#         }    #T_f13ef3ab_03fa_11e9_979c_88e9fe65d0c0row3_col1 {
#             background-color:  #023858;
#         }    #T_f13ef3ab_03fa_11e9_979c_88e9fe65d0c0row3_col2 {
#             background-color:  #023858;
#         }    #T_f13ef3ab_03fa_11e9_979c_88e9fe65d0c0row3_col3 {
#             background-color:  #023858;
#         }    #T_f13ef3ab_03fa_11e9_979c_88e9fe65d0c0row3_col4 {
#             background-color:  #fef6fb;
#         }    #T_f13ef3ab_03fa_11e9_979c_88e9fe65d0c0row3_col5 {
#             background-color:  #f4edf6;
#         }    #T_f13ef3ab_03fa_11e9_979c_88e9fe65d0c0row3_col6 {
#             background-color:  #fff7fb;
#         }    #T_f13ef3ab_03fa_11e9_979c_88e9fe65d0c0row3_col7 {
#             background-color:  #023858;
#         }    #T_f13ef3ab_03fa_11e9_979c_88e9fe65d0c0row3_col8 {
#             background-color:  #023858;
#         }    #T_f13ef3ab_03fa_11e9_979c_88e9fe65d0c0row3_col9 {
#             background-color:  #023858;
#         }    #T_f13ef3ab_03fa_11e9_979c_88e9fe65d0c0row3_col10 {
#             background-color:  #023858;
#         }    #T_f13ef3ab_03fa_11e9_979c_88e9fe65d0c0row3_col11 {
#             background-color:  #fef6fb;
#         }    #T_f13ef3ab_03fa_11e9_979c_88e9fe65d0c0row4_col0 {
#             background-color:  #fff7fb;
#         }    #T_f13ef3ab_03fa_11e9_979c_88e9fe65d0c0row4_col1 {
#             background-color:  #fff7fb;
#         }    #T_f13ef3ab_03fa_11e9_979c_88e9fe65d0c0row4_col2 {
#             background-color:  #fff7fb;
#         }    #T_f13ef3ab_03fa_11e9_979c_88e9fe65d0c0row4_col3 {
#             background-color:  #fff7fb;
#         }    #T_f13ef3ab_03fa_11e9_979c_88e9fe65d0c0row4_col4 {
#             background-color:  #023858;
#         }    #T_f13ef3ab_03fa_11e9_979c_88e9fe65d0c0row4_col5 {
#             background-color:  #fff7fb;
#         }    #T_f13ef3ab_03fa_11e9_979c_88e9fe65d0c0row4_col6 {
#             background-color:  #fff7fb;
#         }    #T_f13ef3ab_03fa_11e9_979c_88e9fe65d0c0row4_col7 {
#             background-color:  #fff7fb;
#         }    #T_f13ef3ab_03fa_11e9_979c_88e9fe65d0c0row4_col8 {
#             background-color:  #fff7fb;
#         }    #T_f13ef3ab_03fa_11e9_979c_88e9fe65d0c0row4_col9 {
#             background-color:  #fff7fb;
#         }    #T_f13ef3ab_03fa_11e9_979c_88e9fe65d0c0row4_col10 {
#             background-color:  #fff7fb;
#         }    #T_f13ef3ab_03fa_11e9_979c_88e9fe65d0c0row4_col11 {
#             background-color:  #023858;
#         }    #T_f13ef3ab_03fa_11e9_979c_88e9fe65d0c0row5_col0 {
#             background-color:  #a4bcda;
#         }    #T_f13ef3ab_03fa_11e9_979c_88e9fe65d0c0row5_col1 {
#             background-color:  #a4bcda;
#         }    #T_f13ef3ab_03fa_11e9_979c_88e9fe65d0c0row5_col2 {
#             background-color:  #a2bcda;
#         }    #T_f13ef3ab_03fa_11e9_979c_88e9fe65d0c0row5_col3 {
#             background-color:  #a2bcda;
#         }    #T_f13ef3ab_03fa_11e9_979c_88e9fe65d0c0row5_col4 {
#             background-color:  #b4c4df;
#         }    #T_f13ef3ab_03fa_11e9_979c_88e9fe65d0c0row5_col5 {
#             background-color:  #023858;
#         }    #T_f13ef3ab_03fa_11e9_979c_88e9fe65d0c0row5_col6 {
#             background-color:  #fff7fb;
#         }    #T_f13ef3ab_03fa_11e9_979c_88e9fe65d0c0row5_col7 {
#             background-color:  #a5bddb;
#         }    #T_f13ef3ab_03fa_11e9_979c_88e9fe65d0c0row5_col8 {
#             background-color:  #a5bddb;
#         }    #T_f13ef3ab_03fa_11e9_979c_88e9fe65d0c0row5_col9 {
#             background-color:  #a4bcda;
#         }    #T_f13ef3ab_03fa_11e9_979c_88e9fe65d0c0row5_col10 {
#             background-color:  #a4bcda;
#         }    #T_f13ef3ab_03fa_11e9_979c_88e9fe65d0c0row5_col11 {
#             background-color:  #b4c4df;
#         }    #T_f13ef3ab_03fa_11e9_979c_88e9fe65d0c0row6_col0 {
#             background-color:  #fff7fb;
#         }    #T_f13ef3ab_03fa_11e9_979c_88e9fe65d0c0row6_col1 {
#             background-color:  #fff7fb;
#         }    #T_f13ef3ab_03fa_11e9_979c_88e9fe65d0c0row6_col2 {
#             background-color:  #fff7fb;
#         }    #T_f13ef3ab_03fa_11e9_979c_88e9fe65d0c0row6_col3 {
#             background-color:  #fff7fb;
#         }    #T_f13ef3ab_03fa_11e9_979c_88e9fe65d0c0row6_col4 {
